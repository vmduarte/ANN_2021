# %% [markdown]
# <a href="https://colab.research.google.com/github/vmduarte/ANN_2021/blob/main/Trab2_RNN_Precipitacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from keras.layers import Input, SimpleRNN, Dense, Flatten, LSTM
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from sklearn import preprocessing

# %%
# !git clone https://github.com/vmduarte/ANN_2021
# %cd ANN_2021
# Out:
# Cloning into 'ANN_2021'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 56 (delta 24), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (56/56), done.
# /content/ANN_2021

# %%
df=pd.read_csv("Trab2_RNN.csv")

# %%
series = np.array(df['Precipitacao'])

# %%
plt.plot(series)

# %%
series = series.reshape(-1, 1)
scaler_X = preprocessing.MinMaxScaler((-1,1)).fit(series)
series =  scaler_X.transform(series)

# %%
P = 10 # period
D = 1
X = []
Y = []
num,col = df.shape

for t in range(num-P):
  t_next = t+ P
  xx = series[t:t_next]
  X.append(xx)
  yy = series[t_next]
  Y.append(yy)

X = np.array(X).reshape(-1,P,1) # data NxDxP
Y = np.array(Y)
print('input shape',X.shape,'output shape',Y.shape )
# Out:
# input shape (182, 10, 1) output shape (182, 1)

# %%
N, cols, other = X.shape
N1 = int(0.8*N)
X_train = X[:N1]
Y_train = Y[:N1]
X_test = X[N1:]
Y_test = Y[N1:]

# %%
X_test.shape
# Out:
# (37, 10, 1)

# %%
model = Sequential()
# Add an Embedding layer expecting input vocab of size 1000, and
# output embedding dimension of size 64.
model.add(Input(shape=(P,1)))

# Add a simpleRNN layer with 5 internal units.
model.add(LSTM(10,'tanh'))
# Add a Dense layer with 1 units.
model.add(Dense(1))
# 
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10)                480
# _________________________________________________________________
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse',optimizer=Adam(lr=0.1))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
r = model.fit(X_train,Y_train,
              epochs=100, 
              validation_data = ( X_test ,Y_test ) )
# Out:
# Epoch 1/100
# 5/5 [==============================] - 21s 154ms/step - loss: 0.4481 - val_loss: 0.2807
# Epoch 2/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1742 - val_loss: 0.2813
# Epoch 3/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1772 - val_loss: 0.2307
# Epoch 4/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1704 - val_loss: 0.2156
# Epoch 5/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1509 - val_loss: 0.1796
# Epoch 6/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1589 - val_loss: 0.1705
# Epoch 7/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1328 - val_loss: 0.1311
# Epoch 8/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1581 - val_loss: 0.1657
# Epoch 9/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1443 - val_loss: 0.1249
# Epoch 10/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1222 - val_loss: 0.1421
# Epoch 11/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1064 - val_loss: 0.1385
# Epoch 12/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1091 - val_loss: 0.1241
# Epoch 13/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1291 - val_loss: 0.1151
# Epoch 14/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0977 - val_loss: 0.1151
# Epoch 15/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1054 - val_loss: 0.1271
# Epoch 16/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0834 - val_loss: 0.1059
# Epoch 17/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0788 - val_loss: 0.1162
# Epoch 18/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0913 - val_loss: 0.1065
# Epoch 19/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1006 - val_loss: 0.1110
# Epoch 20/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0743 - val_loss: 0.1197
# Epoch 21/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0897 - val_loss: 0.1128
# Epoch 22/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0819 - val_loss: 0.1300
# Epoch 23/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0997 - val_loss: 0.1086
# Epoch 24/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0767 - val_loss: 0.1251
# Epoch 25/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0881 - val_loss: 0.1254
# Epoch 26/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0873 - val_loss: 0.1194
# Epoch 27/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0947 - val_loss: 0.1202
# Epoch 28/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0910 - val_loss: 0.1407
# Epoch 29/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0774 - val_loss: 0.1313
# Epoch 30/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0798 - val_loss: 0.1341
# Epoch 31/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0839 - val_loss: 0.1479
# Epoch 32/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0807 - val_loss: 0.1393
# Epoch 33/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0715 - val_loss: 0.1081
# Epoch 34/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0705 - val_loss: 0.1522
# Epoch 35/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0707 - val_loss: 0.1239
# Epoch 36/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0819 - val_loss: 0.1468
# Epoch 37/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0613 - val_loss: 0.1417
# Epoch 38/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0705 - val_loss: 0.1319
# Epoch 39/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0803 - val_loss: 0.1399
# Epoch 40/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0809 - val_loss: 0.1446
# Epoch 41/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0597 - val_loss: 0.1618
# Epoch 42/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0650 - val_loss: 0.1517
# Epoch 43/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0710 - val_loss: 0.1273
# Epoch 44/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0843 - val_loss: 0.2044
# Epoch 45/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0699 - val_loss: 0.1549
# Epoch 46/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0480 - val_loss: 0.2013
# Epoch 47/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0664 - val_loss: 0.1720
# Epoch 48/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0515 - val_loss: 0.2265
# Epoch 49/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0627 - val_loss: 0.1486
# Epoch 50/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0825 - val_loss: 0.1485
# Epoch 51/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0653 - val_loss: 0.2161
# Epoch 52/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0788 - val_loss: 0.1726
# Epoch 53/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0582 - val_loss: 0.1807
# Epoch 54/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0492 - val_loss: 0.2487
# Epoch 55/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0409 - val_loss: 0.2378
# Epoch 56/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0414 - val_loss: 0.1705
# Epoch 57/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0705 - val_loss: 0.2078
# Epoch 58/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0396 - val_loss: 0.2144
# Epoch 59/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0464 - val_loss: 0.2564
# Epoch 60/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0502 - val_loss: 0.1875
# Epoch 61/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0542 - val_loss: 0.2034
# Epoch 62/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0635 - val_loss: 0.1650
# Epoch 63/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0638 - val_loss: 0.2139
# Epoch 64/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0462 - val_loss: 0.1884
# Epoch 65/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0492 - val_loss: 0.2427
# Epoch 66/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0512 - val_loss: 0.1742
# Epoch 67/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0656 - val_loss: 0.2034
# Epoch 68/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0391 - val_loss: 0.2136
# Epoch 69/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0589 - val_loss: 0.1690
# Epoch 70/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0434 - val_loss: 0.1907
# Epoch 71/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0539 - val_loss: 0.1862
# Epoch 72/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0423 - val_loss: 0.1941
# Epoch 73/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0383 - val_loss: 0.2585
# Epoch 74/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0486 - val_loss: 0.2505
# Epoch 75/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0327 - val_loss: 0.2442
# Epoch 76/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0227 - val_loss: 0.2561
# Epoch 77/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0262 - val_loss: 0.2737
# Epoch 78/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0217 - val_loss: 0.2738
# Epoch 79/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.2476
# Epoch 80/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0354 - val_loss: 0.2749
# Epoch 81/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0299 - val_loss: 0.2885
# Epoch 82/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0374 - val_loss: 0.2756
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0404 - val_loss: 0.2565
# Epoch 84/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0361 - val_loss: 0.2601
# Epoch 85/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0408 - val_loss: 0.1995
# Epoch 86/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0399 - val_loss: 0.2832
# Epoch 87/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0411 - val_loss: 0.2420
# Epoch 88/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0347 - val_loss: 0.2483
# Epoch 89/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0320 - val_loss: 0.3092
# Epoch 90/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0365 - val_loss: 0.2886
# Epoch 91/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0298 - val_loss: 0.3054
# Epoch 92/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0288 - val_loss: 0.3301
# Epoch 93/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0264 - val_loss: 0.2886
# Epoch 94/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0310 - val_loss: 0.2728
# Epoch 95/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0240 - val_loss: 0.3016
# Epoch 96/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0231 - val_loss: 0.2574
# Epoch 97/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0250 - val_loss: 0.2749
# Epoch 98/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0246 - val_loss: 0.2373
# Epoch 99/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0282 - val_loss: 0.2568
# Epoch 100/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0293 - val_loss: 0.2646

# %%
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %%
pred_Y = model.predict(X_test)

pred_Y  = scaler_X.inverse_transform(np.array(pred_Y ).reshape(-1,1))
Y_test = scaler_X.inverse_transform(np.array(Y_test).reshape(-1,1))

# %%
# this is a wrong way to do....

plt.plot(Y_test, label='prediction target')
plt.plot(pred_Y, label='prediction forecast')

# %%
pred_test = []
for xi in X_test:
  yi = model.predict(xi.reshape(1,-1,1))[0,0]
  pred_test.append(yi)

pred_test  = scaler_X.inverse_transform(np.array(pred_test).reshape(-1,1))

# %%
plt.plot(Y_test, label='prediction target')
plt.plot(pred_test, label='prediction forecast')

# %%
X_train.shape
# Out:
# (145, 10, 1)

# %%
X_test.shape
# Out:
# (37, 10, 1)
