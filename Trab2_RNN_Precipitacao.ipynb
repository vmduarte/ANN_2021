# %% [markdown]
# <a href="https://colab.research.google.com/github/vmduarte/ANN_2021/blob/main/Trab2_RNN_Precipitacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from keras.layers import Input, SimpleRNN, Dense, Flatten, LSTM
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from sklearn import preprocessing

# %%
# !git clone https://github.com/vmduarte/ANN_2021
# %cd ANN_2021
# Out:
# Cloning into 'ANN_2021'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 59 (delta 26), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (59/59), done.
# /content/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021/ANN_2021

# %%
df=pd.read_csv("Trab2_RNN.csv")

# %%
series = np.array(df['Precipitacao'])

# %%
plt.plot(series)

# %%
series = series.reshape(-1, 1)
scaler_X = preprocessing.MinMaxScaler((-1,1)).fit(series)
series =  scaler_X.transform(series)

# %%
P = 25 # period
D = 1
X = []
Y = []
num,col = df.shape

for t in range(num-P):
  t_next = t+ P
  xx = series[t:t_next]
  X.append(xx)
  yy = series[t_next]
  Y.append(yy)

X = np.array(X).reshape(-1,P,1) # data NxDxP
Y = np.array(Y)
print('input shape',X.shape,'output shape',Y.shape )
# Out:
# input shape (167, 25, 1) output shape (167, 1)

# %%
N, cols, other = X.shape
N1 = int(0.5*N)
X_train = X[:N1]
Y_train = Y[:N1]
X_test = X[N1:]
Y_test = Y[N1:]

# %%
X_test.shape
# Out:
# (84, 25, 1)

# %%
model = Sequential()
# Add an Embedding layer expecting input vocab of size 1000, and
# output embedding dimension of size 64.
model.add(Input(shape=(P,1)))

# Add a simpleRNN layer with 5 internal units.
model.add(LSTM(10,'tanh'))
# Add a Dense layer with 1 units.
model.add(Dense(1))
# 
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 10)                480
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse',optimizer=Adam(lr=0.1))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
r = model.fit(X_train,Y_train,
              epochs=100, 
              validation_data = ( X_test ,Y_test ) )
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 221ms/step - loss: 0.6703 - val_loss: 0.4199
# Epoch 2/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3917 - val_loss: 0.3194
# Epoch 3/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2651 - val_loss: 0.2383
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1737 - val_loss: 0.2561
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1707 - val_loss: 0.2980
# Epoch 6/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1900 - val_loss: 0.2604
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1644 - val_loss: 0.2405
# Epoch 8/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1715 - val_loss: 0.2367
# Epoch 9/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1616 - val_loss: 0.2347
# Epoch 10/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1499 - val_loss: 0.2335
# Epoch 11/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1531 - val_loss: 0.2331
# Epoch 12/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1418 - val_loss: 0.2340
# Epoch 13/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1619 - val_loss: 0.2300
# Epoch 14/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1789 - val_loss: 0.2237
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1471 - val_loss: 0.2204
# Epoch 16/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1556 - val_loss: 0.2159
# Epoch 17/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1502 - val_loss: 0.2129
# Epoch 18/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1523 - val_loss: 0.2104
# Epoch 19/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1543 - val_loss: 0.2074
# Epoch 20/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1527 - val_loss: 0.2059
# Epoch 21/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1356 - val_loss: 0.2023
# Epoch 22/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1451 - val_loss: 0.1970
# Epoch 23/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1370 - val_loss: 0.1928
# Epoch 24/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1407 - val_loss: 0.1897
# Epoch 25/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1418 - val_loss: 0.1910
# Epoch 26/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1422 - val_loss: 0.1832
# Epoch 27/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1310 - val_loss: 0.1746
# Epoch 28/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1301 - val_loss: 0.1757
# Epoch 29/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1168 - val_loss: 0.1776
# Epoch 30/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1339 - val_loss: 0.1572
# Epoch 31/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1096 - val_loss: 0.1505
# Epoch 32/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1198 - val_loss: 0.1461
# Epoch 33/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0987 - val_loss: 0.1664
# Epoch 34/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0906 - val_loss: 0.1316
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0939 - val_loss: 0.1465
# Epoch 36/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0930 - val_loss: 0.1582
# Epoch 37/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0761 - val_loss: 0.1458
# Epoch 38/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1082 - val_loss: 0.1560
# Epoch 39/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0859 - val_loss: 0.1456
# Epoch 40/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1034 - val_loss: 0.1436
# Epoch 41/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0810 - val_loss: 0.1660
# Epoch 42/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0940 - val_loss: 0.1421
# Epoch 43/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0820 - val_loss: 0.1431
# Epoch 44/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0815 - val_loss: 0.1506
# Epoch 45/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1056 - val_loss: 0.1515
# Epoch 46/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0879 - val_loss: 0.1389
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0827 - val_loss: 0.1313
# Epoch 48/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0940 - val_loss: 0.1452
# Epoch 49/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0741 - val_loss: 0.1484
# Epoch 50/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0846 - val_loss: 0.1412
# Epoch 51/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0787 - val_loss: 0.1397
# Epoch 52/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0751 - val_loss: 0.1420
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0658 - val_loss: 0.1630
# Epoch 54/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0904 - val_loss: 0.1459
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0866 - val_loss: 0.1416
# Epoch 56/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0746 - val_loss: 0.1606
# Epoch 57/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0887 - val_loss: 0.1588
# Epoch 58/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0828 - val_loss: 0.1458
# Epoch 59/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0948 - val_loss: 0.1294
# Epoch 60/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0878 - val_loss: 0.1525
# Epoch 61/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0758 - val_loss: 0.1628
# Epoch 62/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0677 - val_loss: 0.1395
# Epoch 63/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0721 - val_loss: 0.1340
# Epoch 64/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0676 - val_loss: 0.1566
# Epoch 65/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0741 - val_loss: 0.1502
# Epoch 66/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0729 - val_loss: 0.1702
# Epoch 67/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0768 - val_loss: 0.1461
# Epoch 68/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0768 - val_loss: 0.1451
# Epoch 69/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0723 - val_loss: 0.1576
# Epoch 70/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0742 - val_loss: 0.1572
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0783 - val_loss: 0.1457
# Epoch 72/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0754 - val_loss: 0.1376
# Epoch 73/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0764 - val_loss: 0.1490
# Epoch 74/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0808 - val_loss: 0.1688
# Epoch 75/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0804 - val_loss: 0.1478
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0702 - val_loss: 0.1354
# Epoch 77/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0817 - val_loss: 0.1494
# Epoch 78/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0722 - val_loss: 0.1531
# Epoch 79/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0742 - val_loss: 0.1863
# Epoch 80/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0758 - val_loss: 0.1708
# Epoch 81/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0762 - val_loss: 0.1873
# Epoch 82/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0876 - val_loss: 0.1558
# Epoch 83/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0706 - val_loss: 0.1501
# Epoch 84/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0698 - val_loss: 0.1514
# Epoch 85/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0712 - val_loss: 0.1569
# Epoch 86/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0689 - val_loss: 0.1640
# Epoch 87/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0587 - val_loss: 0.1572
# Epoch 88/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0597 - val_loss: 0.1464
# Epoch 89/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0645 - val_loss: 0.1493
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0554 - val_loss: 0.1391
# Epoch 91/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0686 - val_loss: 0.1498
# Epoch 92/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0658 - val_loss: 0.1707
# Epoch 93/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0570 - val_loss: 0.1629
# Epoch 94/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0457 - val_loss: 0.1791
# Epoch 95/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0611 - val_loss: 0.1429
# Epoch 96/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0652 - val_loss: 0.1381
# Epoch 97/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0474 - val_loss: 0.1830
# Epoch 98/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0706 - val_loss: 0.1624
# Epoch 99/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0512 - val_loss: 0.1866
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0602 - val_loss: 0.1544

# %%
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %%
pred_Y = model.predict(X_test)

pred_Y  = scaler_X.inverse_transform(np.array(pred_Y ).reshape(-1,1))
Y_test = scaler_X.inverse_transform(np.array(Y_test).reshape(-1,1))

# %%
# this is a wrong way to do....

plt.plot(Y_test, label='prediction target')
plt.plot(pred_Y, label='prediction forecast')

# %%
pred_test = []
for xi in X_test:
  yi = model.predict(xi.reshape(1,-1,1))[0,0]
  pred_test.append(yi)

pred_test  = scaler_X.inverse_transform(np.array(pred_test).reshape(-1,1))

# %%
plt.plot(Y_test, label='prediction target')
plt.plot(pred_test, label='prediction forecast')

# %%
X_train.shape
# Out:
# (83, 25, 1)

# %%
X_test.shape
# Out:
# (84, 25, 1)
